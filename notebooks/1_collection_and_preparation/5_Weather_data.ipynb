# %%
import pandas as pd
import numpy as np
from pathlib import Path
import energizer

pd.set_option('display.max_columns', None)

# %%
df = energizer.io.read_all_files()
df
# Out:
#           trip_id  taxi_id trip_start_timestamp  trip_end_timestamp  \
# 0              86        0  2013-01-01 00:15:00 2013-01-01 00:30:00
# 1             154        1  2013-01-01 00:15:00 2013-01-01 00:30:00
# 2             155        2  2013-01-01 00:15:00 2013-01-01 00:15:00
# 3             156        3  2013-01-01 00:15:00 2013-01-01 00:30:00
# 4             157        4  2013-01-01 00:15:00 2013-01-01 00:15:00
# ...           ...      ...                  ...                 ...
# 8749272  15047982      581  2013-12-31 23:15:00 2013-12-31 23:15:00
# 8749273  15047983     1131  2013-12-31 23:15:00 2013-12-31 23:45:00
# 8749274  15047984     2509  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749275  15047986      451  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749276  15047987      350  2013-12-31 23:15:00 2013-12-31 23:45:00
#
#          trip_seconds  trip_miles   fare  tips  tolls  extras  trip_total  \
# 0               480.0         3.8  10.65   2.0    0.0     1.0       13.65
# ...

# %% [markdown]
# ### Weather Data

# %% [markdown]
# Merge the Dataframe and the Weather Data

# %%
# def merge_with_df():
df_weather= pd.read_csv("../../data/input/weather/Weather_Hourly_2013.csv")

# %%
def merge_weather(df,df_weather):
    df_weather["datetime"]=pd.to_datetime(df_weather['datetime'])
    df_weather.rename(columns={"datetime": "round_datetime" }, inplace=True)
    # eine Spalte mit Datum
    df["round_datetime"] = df['trip_start_timestamp'].dt.round('H')
    df = pd.merge(df, df_weather, on="round_datetime", how='left') #merge city data with weather data
    df=df.drop("round_datetime", 1)
    return df

# %%
df=merge_weather(df,df_weather)

# %%
df.drop(columns=["humidity_x", "temperature_x", "humidity_y", "temperature_y"], inplace=True)
df
# Out:
#          trip_id  taxi_id trip_start_timestamp  trip_end_timestamp  \
# 0              0        0  2013-01-01 00:15:00 2013-01-01 00:30:00
# 1              1        1  2013-01-01 00:15:00 2013-01-01 00:30:00
# 2              2        2  2013-01-01 00:15:00 2013-01-01 00:15:00
# 3              3        3  2013-01-01 00:15:00 2013-01-01 00:30:00
# 4              4        4  2013-01-01 00:15:00 2013-01-01 00:15:00
# ...          ...      ...                  ...                 ...
# 8749272  8749272      581  2013-12-31 23:15:00 2013-12-31 23:15:00
# 8749273  8749273     1131  2013-12-31 23:15:00 2013-12-31 23:45:00
# 8749274  8749274     2509  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749275  8749275      451  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749276  8749276      350  2013-12-31 23:15:00 2013-12-31 23:45:00
#
#          trip_seconds  trip_miles   fare  tips  tolls  extras  trip_total  \
# 0               480.0         3.8  10.65   2.0    0.0     1.0       13.65
# ...

# %%
energizer.io.cleaning_loop(df)
# Out:
# Let the cleaning begin ...
# Dropped duplicates
# Dropped nan values for better data quality
# Replaced trip_id
# Replaced taxi_id
# Changed numeric types
# Changed datetime types
# Changed string types
# Cutted years
# Filtered extreme values
# Saving/Overwriting in progress ...
# First split
# Second split
# Third split
# Forth split
# Saved No. 1
# Saved No. 2
# Saved No. 3
# Saved No. 4
#          trip_id  taxi_id trip_start_timestamp  trip_end_timestamp  \
# 0              0        0  2013-01-01 00:15:00 2013-01-01 00:30:00
# 1              1        1  2013-01-01 00:15:00 2013-01-01 00:30:00
# 2              2        2  2013-01-01 00:15:00 2013-01-01 00:15:00
# 3              3        3  2013-01-01 00:15:00 2013-01-01 00:30:00
# 4              4        4  2013-01-01 00:15:00 2013-01-01 00:15:00
# ...          ...      ...                  ...                 ...
# 8749272  8749272      581  2013-12-31 23:15:00 2013-12-31 23:15:00
# ...

# %%
energizer.io.cleaning_loop(df, sample_set=True)
# Out:
# Let the cleaning begin ...
# Dropped duplicates
# Dropped nan values for better data quality
# Replaced trip_id
# Replaced taxi_id
# Changed numeric types
# Changed datetime types
# Changed string types
# Cutted years
# Filtered extreme values
# Sample set created
#          trip_id  taxi_id trip_start_timestamp  trip_end_timestamp  \
# 2748594  2748594      177  2013-05-18 20:00:00 2013-05-18 20:00:00
# 6221783  6221783     2145  2013-10-11 10:15:00 2013-10-11 10:15:00
# 3154610  3154610     1380  2013-06-06 14:45:00 2013-06-06 15:15:00
# 7832169  7832169      686  2013-12-04 21:45:00 2013-12-04 22:00:00
# 7617358  7617358     2645  2013-11-26 11:00:00 2013-11-26 11:30:00
# ...          ...      ...                  ...                 ...
# 7487395  7487395     2844  2013-11-22 02:15:00 2013-11-22 02:15:00
# 7798797  7798797      779  2013-12-03 20:45:00 2013-12-03 20:45:00
# 8040492  8040492      784  2013-12-10 09:30:00 2013-12-10 09:45:00
# ...

# %%
trip_data = energizer.io.read_all_files()
print('read in trip_data')
geojson = energizer.io.read_all_files(filetype='geojson')
geojson.head()
# Out:
# read in trip_data
#   statefp10 name10 commarea_n         namelsad10 commarea      geoid10 notes  \
# 0        17   8424         44  Census Tract 8424       44  17031842400
# 1        17   8403         59  Census Tract 8403       59  17031840300
# 2        17   8411         34  Census Tract 8411       34  17031841100
# 3        17   8412         31  Census Tract 8412       31  17031841200
# 4        17   8390         32  Census Tract 8390       32  17031839000
#
#   tractce10 countyfp10                                           geometry
# 0    842400        031  MULTIPOLYGON (((-87.62405 41.73022, -87.62405 ...
# 1    840300        031  MULTIPOLYGON (((-87.68608 41.82296, -87.68607 ...
# 2    841100        031  MULTIPOLYGON (((-87.62935 41.85280, -87.62934 ...
# 3    841200        031  MULTIPOLYGON (((-87.68813 41.85569, -87.68816 ...
# 4    839000        031  MULTIPOLYGON (((-87.63312 41.87449, -87.63306 ...

# %%
trip_data_h3_7 = energizer.vis.generate_hexagons(trip_data, h3_resolution=7)
energizer.vis.saving_hexagons(trip_data_h3_7, resolution = 'hex_res_7')
# Out:
# 8749277it [18:30, 7882.03it/s]
# Saving/Overwriting in progress ...
# First split
# Second split
# Third split
# Forth split
# Saved No. 1
# Saved No. 2
# Saved No. 3
# Saved No. 4
# Saving job finished

# %%
trip_data_h3_8 = energizer.vis.generate_hexagons(trip_data, h3_resolution=8)
energizer.vis.saving_hexagons(trip_data_h3_8, resolution = 'hex_res_8')
# Out:
# 8749277it [20:36, 7077.09it/s]
# Saving/Overwriting in progress ...
# First split
# Second split
# Third split
# Forth split
# Saved No. 1
# Saved No. 2
# Saved No. 3
# Saved No. 4
# Saving job finished

# %%
trip_data_h3_9 = energizer.vis.generate_hexagons(trip_data, h3_resolution=9)
energizer.vis.saving_hexagons(trip_data_h3_9, resolution = 'hex_res_9')
# Out:
# 8749277it [18:27, 7902.45it/s]
# Saving/Overwriting in progress ...
# First split
# Second split
# Third split
# Forth split
# Saved No. 1
# Saved No. 2
# Saved No. 3
# Saved No. 4
# Saving job finished

# %%
trip_data_h3_10 = energizer.vis.generate_hexagons(trip_data, h3_resolution=10)
energizer.vis.saving_hexagons(trip_data_h3_10, resolution = 'hex_res_10')
# Out:
# 8749277it [18:13, 8004.73it/s]
# Saving/Overwriting in progress ...
# First split
# Second split
# Third split
# Forth split
# Saved No. 1
# Saved No. 2
# Saved No. 3
# Saved No. 4
# Saving job finished

# %%
trip_data_h3_10
# Out:
#          trip_id  taxi_id trip_start_timestamp  trip_end_timestamp  \
# 0              0        0  2013-01-01 00:15:00 2013-01-01 00:30:00
# 1              1        1  2013-01-01 00:15:00 2013-01-01 00:30:00
# 2              2        2  2013-01-01 00:15:00 2013-01-01 00:15:00
# 3              3        3  2013-01-01 00:15:00 2013-01-01 00:30:00
# 4              4        4  2013-01-01 00:15:00 2013-01-01 00:15:00
# ...          ...      ...                  ...                 ...
# 8749272  8749272      581  2013-12-31 23:15:00 2013-12-31 23:15:00
# 8749273  8749273     1131  2013-12-31 23:15:00 2013-12-31 23:45:00
# 8749274  8749274     2509  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749275  8749275      451  2013-12-31 23:15:00 2013-12-31 23:30:00
# 8749276  8749276      350  2013-12-31 23:15:00 2013-12-31 23:45:00
#
#          trip_seconds  trip_miles   fare  tips  tolls  extras  trip_total  \
# 0               480.0         3.8  10.65   2.0    0.0     1.0       13.65
# ...
